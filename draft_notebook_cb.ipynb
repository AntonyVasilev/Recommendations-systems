# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 100)

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

# Модель второго уровня
from catboost import CatBoost, CatBoostClassifier

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

os.environ['MKL_NUM_THREADS'] = '1'

from src.metrics import precision_at_k, recall_at_k
from src.utils import prefilter_items
import src.features as ft
from src.recommenders import MainRecommender

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./data/retail_train.csv')
item_features = pd.read_csv('./data/product.csv')
user_features = pd.read_csv('./data/hh_demographic.csv')

# %%
ITEM_COL = 'item_id'
USER_COL = 'user_id'
ACTUAL_COL = 'actual'

# N = Neighbors
N_PREDICT = 10

# %% [markdown]
# # Подготовка фичей датасета

# %%
# column processing
item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': ITEM_COL}, inplace=True)
user_features.rename(columns={'household_key': USER_COL }, inplace=True)

# %% [markdown]
# # Split dataset for train, eval, test

# %%
VAL_MATCHER_WEEKS = 6
VAL_RANKER_WEEKS = 3

# %%
# берем данные для тренировки matching модели
data_train_matcher = data[data['week_no'] < data['week_no'].max() - (VAL_MATCHER_WEEKS + VAL_RANKER_WEEKS)]

# берем данные для валидации matching модели
data_val_matcher = data[(data['week_no'] >= data['week_no'].max() - (VAL_MATCHER_WEEKS + VAL_RANKER_WEEKS)) &
                      (data['week_no'] < data['week_no'].max() - (VAL_RANKER_WEEKS))]


# берем данные для тренировки ranking модели
data_train_ranker = data_val_matcher.copy()  # Для наглядности. Далее мы добавим изменения, и они будут отличаться

# берем данные для теста ranking, matching модели
data_val_ranker = data[data['week_no'] >= data['week_no'].max() - VAL_RANKER_WEEKS]

# %%
# сделаем объединенный сет данных для первого уровня (матчинга)
df_join_train_matcher = pd.concat([data_train_matcher, data_val_matcher])

# %%
def print_stats_data(df_data, name_df):
    print(name_df)
    print(f"Shape: {df_data.shape} Users: {df_data[USER_COL].nunique()} Items: {df_data[ITEM_COL].nunique()}")

# %%
print_stats_data(data_train_matcher,'train_matcher')
print_stats_data(data_val_matcher,'val_matcher')
print_stats_data(data_train_ranker,'train_ranker')
print_stats_data(data_val_ranker,'val_ranker')
# Out:
# train_matcher
# Shape: (2108779, 12) Users: 2498 Items: 83685
# val_matcher
# Shape: (169711, 12) Users: 2154 Items: 27649
# train_ranker
# Shape: (169711, 12) Users: 2154 Items: 27649
# val_ranker
# Shape: (118314, 12) Users: 2042 Items: 24329

# %%
data_train_matcher.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0

# %% [markdown]
# # Prefilter items

# %%
# Определю количество наиболее популярных товаров, которые составляют 90% продаж
items_by_poprularity = data_train_matcher.groupby(by='item_id')['basket_id'].nunique(). \
    reset_index().sort_values(by='basket_id', ascending=False)
items_by_poprularity.rename(columns={'basket_id': 'n_purchases'}, inplace=True)
items_by_poprularity.head()
# Out:
#        item_id  n_purchases
# 34192  1082185        24318
# 54389  6534178        16233
# 28450  1029743        11661
# 24657   995242        10226
# 36790  1106523         8011

# %%
purchses_sum = items_by_poprularity.n_purchases.sum()
top_90_percent_items_list = []
purchses_commul_sum = 0
for item, n_purchases in zip(items_by_poprularity.item_id, items_by_poprularity.n_purchases):
    purchses_commul_sum += n_purchases
    if (purchses_commul_sum / purchses_sum) < 0.9:
        top_90_percent_items_list.append(item)
    else:
        break

n_popular = len(top_90_percent_items_list)
n_popular
# Out:
# 18714

# %%
# Оставляю в датасете только 18714 товаров. Id остальных заменю на 999999
n_items_before = data_train_matcher['item_id'].nunique()

data_train_matcher = prefilter_items(data_train_matcher, item_features=item_features, 
                                     take_n_popular=n_popular)

n_items_after = data_train_matcher['item_id'].nunique()
print(f'Decreased # items from {n_items_before} to {n_items_after}')
# Out:
# Decreased # items from 83685 to 18715

# %% [markdown]
# # Make cold-start to warm-start

# %%
# ищем общих пользователей
common_users = data_train_matcher.user_id.values

data_val_matcher = data_val_matcher[data_val_matcher.user_id.isin(common_users)]
data_train_ranker = data_train_ranker[data_train_ranker.user_id.isin(common_users)]
data_val_ranker = data_val_ranker[data_val_ranker.user_id.isin(common_users)]

print_stats_data(data_train_matcher,'train_matcher')
print_stats_data(data_val_matcher,'val_matcher')
print_stats_data(data_train_ranker,'train_ranker')
print_stats_data(data_val_ranker,'val_ranker')
# Out:
# train_matcher
# Shape: (861404, 13) Users: 2495 Items: 18715
# val_matcher
# Shape: (169615, 12) Users: 2151 Items: 27644
# train_ranker
# Shape: (169615, 12) Users: 2151 Items: 27644
# val_ranker
# Shape: (118282, 12) Users: 2040 Items: 24325

# %% [markdown]
# # Grid search

# %%
# from itertools import product

# %%
# weightings_list = ['bm25', 'tfidf']
# model_type_list = ['als', 'bpr']
# user_item_matrix_values = ['binary', 'sales_value', 'purchase_sum']
# own_recommender_type_list = ['item-item', 'cosine', 'tfidf']
# recs_type_list = ['own', 'rec', 'itm', 'usr']

# %%
# result_dict = {
#     'weighting': [],
#     'model_type': [],
#     'own_recommender_type': [],
#     'user_item_matrix_values': [],
#     'own_recall': [],
#     'rec_recall': [],
#     'itm_recall': [],
#     'usr_recall': []
# }

# %%
# %%time
# for ui_value, weighting, model_type, own_recommender in product(
#             user_item_matrix_values, weightings_list, model_type_list, own_recommender_type_list):
#     base_recommender = MainRecommender(data_train_matcher, weighting=weighting, 
#                                        model_type=model_type, own_recommender_type=own_recommender, 
#                                        user_item_matrix_values=ui_value)
#     result_dict['weighting'].append(weighting)
#     result_dict['model_type'].append(model_type)
#     result_dict['own_recommender_type'].append(own_recommender)
#     result_dict['user_item_matrix_values'].append(ui_value)
    
#     for el in recs_type_list:
#         res = base_recommender.evalMetrics(metric_type='recall', df_result=data_val_matcher, 
#                         target_col_name=USER_COL, recommend_model_type=el, N_PREDICT=N_PREDICT)
#         result_dict[el + '_recall'].append(res)

# %%
# result_df = pd.DataFrame(result_dict)
# result_df

# %%
# for col in result_df.columns.to_list()[4:]:
#     print(f'Best {col}:\n{result_df.loc[np.argmax(result_df[col]), :]}')
#     print('*' * 30)

# %% [markdown]
# # Init/train recommender

# %%
recommender = MainRecommender(data_train_matcher, weighting='tfidf',
                             model_type='als', own_recommender_type='cosine',
                             user_item_matrix_values='binary')

# %% [markdown]
# ### Recall@50 of matching

# %%
recs_type_list = ['own', 'rec', 'itm', 'usr']

# %%
TOPK_RECALL = 10

# %%
# for el in recs_type_list:
#     res = recommender.evalMetrics(metric_type='recall', df_result=data_val_matcher, 
#                     target_col_name=USER_COL, recommend_model_type=el, N_PREDICT=TOPK_RECALL)
#     print(f'{el} recall: {res}')

# %% [markdown]
# ### Precision@5 of matching

# %%
TOPK_PRECISION = 5

# %%
# for el in recs_type_list:
#     res = recommender.evalMetrics(metric_type='precision', df_result=data_val_matcher, 
#                     target_col_name=USER_COL, recommend_model_type=el, N_PREDICT=TOPK_PRECISION)
#     print(f'{el} precision: {res}')

# %% [markdown]
# # Ranking part

# %% [markdown]
# ## Подготовка данных для трейна

# %%
# взяли пользователей из трейна для ранжирования
df_match_candidates = pd.DataFrame(data_train_ranker[USER_COL].unique())
df_match_candidates.columns = [USER_COL]

# %%
# собираем кандитатов с первого этапа (matcher)
df_match_candidates['candidates'] = df_match_candidates[USER_COL].apply(
    lambda x: recommender.get_own_recommendations(x, N=N_PREDICT))

# %%
df_match_candidates.head(2)
# Out:
#    user_id                                         candidates
# 0     2070  [1029743, 913210, 1105426, 933067, 838186, 109...
# 1     2021  [1119454, 950935, 1041390, 844179, 1013928, 65...

# %%
df_items = df_match_candidates.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().reset_index(level=1, drop=True)
df_items.name = 'item_id'

# %%
df_match_candidates = df_match_candidates.drop('candidates', axis=1).join(df_items)

# %%
df_match_candidates.head(4)
# Out:
#    user_id  item_id
# 0     2070  1029743
# 0     2070   913210
# 0     2070  1105426
# 0     2070   933067

# %% [markdown]
# ### Check warm start

# %%
print_stats_data(df_match_candidates, 'match_candidates')
# Out:
# match_candidates
# Shape: (21510, 2) Users: 2151 Items: 6322

# %% [markdown]
# ### Создаем трейн сет для ранжирования с учетом кандидатов с этапа 1

# %%
df_ranker_train = data_train_ranker[[USER_COL, ITEM_COL]].copy()
df_ranker_train['target'] = 1  # тут только покупки

# %%
df_ranker_train.head()
# Out:
#          user_id  item_id  target
# 2104867     2070  1019940       1
# 2107468     2021   840361       1
# 2107469     2021   856060       1
# 2107470     2021   869344       1
# 2107471     2021   896862       1

# %% [markdown]
# #### Не хватает нулей в датасете, поэтому добавляем наших кандитатов в качество нулей

# %%
df_ranker_train = df_match_candidates.merge(df_ranker_train, on=[USER_COL, ITEM_COL], how='left')

# чистим дубликаты
df_ranker_train = df_ranker_train.drop_duplicates(subset=[USER_COL, ITEM_COL])

df_ranker_train['target'].fillna(0, inplace= True)

# %%
df_ranker_train.target.value_counts()
# Out:
# 0.0    15950
# 1.0     5556
# Name: target, dtype: int64

# %%
df_ranker_train.head(2)
# Out:
#    user_id  item_id  target
# 0     2070  1029743     0.0
# 1     2070   913210     1.0

# %% [markdown]
# ## Подготавливаем фичи для обучения модели

# %%
item_features.head(2)
# Out:
#    item_id  manufacturer    department     brand            commodity_desc  \
# 0    25671             2       GROCERY  National                  FRZN ICE
# 1    26081             2  MISC. TRANS.  National  NO COMMODITY DESCRIPTION
#
#             sub_commodity_desc curr_size_of_product
# 0          ICE - CRUSHED/CUBED                22 LB
# 1  NO SUBCOMMODITY DESCRIPTION

# %%
user_features.head(2)
# Out:
#   age_desc marital_status_code income_desc homeowner_desc      hh_comp_desc  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
#
#   household_size_desc kid_category_desc  user_id
# 0                   2      None/Unknown        1
# 1                   2      None/Unknown        7

# %%
df_ranker_train = df_ranker_train.merge(item_features, on='item_id', how='left')
df_ranker_train = df_ranker_train.merge(user_features, on='user_id', how='left')

df_ranker_train.head(2)
# Out:
#    user_id  item_id  target  manufacturer department     brand  \
# 0     2070  1029743     0.0            69    GROCERY   Private
# 1     2070   913210     1.0             2    GROCERY  National
#
#                    commodity_desc              sub_commodity_desc  \
# 0             FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 1  WATER - CARBONATED/FLVRD DRINK  NON-CRBNTD DRNKING/MNERAL WATE
#
#   curr_size_of_product age_desc marital_status_code income_desc  \
# 0                 1 GA    45-54                   U      50-74K
# 1             405.6 OZ    45-54                   U      50-74K
#
#   homeowner_desc hh_comp_desc household_size_desc kid_category_desc
# 0        Unknown      Unknown                   1      None/Unknown
# 1        Unknown      Unknown                   1      None/Unknown

# %% [markdown]
# ### Добавляю новые фичи в датасет

# %% [markdown]
# Заказ товара в последних 5 покупках в виде последовательности бит (категориальная).

# %%
last_5_purchases_as_bit_array = ft.get_last_5_purchases_as_bit_array(data_train_ranker, item_features)
df_ranker_train = df_ranker_train.merge(last_5_purchases_as_bit_array, on=['item_id'], how='left')

# %% [markdown]
# #### user_id

# %%
# Средняя сумма покупки 1 товара в каждой категории
mean_purchase_by_department= ft.get_mean_purchase_per_item_by_department(data_train_ranker, 
                                                                      item_features)
df_ranker_train = df_ranker_train.merge(mean_purchase_by_department[['user_id', 
                        'department', 'mean_purchase']], on=['user_id', 'department'], how='left')

# Кол-во покупок в каждой категории
num_purchases_by_department = ft.get_num_purchases_per_department(data_train_ranker, item_features)
df_ranker_train = df_ranker_train.merge(num_purchases_by_department[['user_id', 'department', 
                                        'num_purchases']], on=['user_id', 'department'], how='left')

# Доля покупок утром/днем/вечером
user_trans_df = ft.get_proportion_of_purchases_by_times_of_day(data_train_ranker)
df_ranker_train = df_ranker_train.merge(user_trans_df, on='user_id', how='left')

# %% [markdown]
# #### item_id

# %%
# Кол-во покупок в неделю
week_purchases_df = ft.get_num_purchases_per_week(data_train_ranker)
df_ranker_train = df_ranker_train.merge(week_purchases_df[['item_id', 'n_purchases_per_week']], 
                                        on=['item_id'], how='left')

# Среднее кол-во покупок 1 товара в категории в неделю
mean_n_purchases_per_week = ft.get_mean_num_purchases_per_item_dept_week(data_train_ranker, 
                                                                      item_features)
df_ranker_train = df_ranker_train.merge(mean_n_purchases_per_week[['department', 
                                        'mean_n_purchases_per_week']], on=['department'], how='left')

# (Кол-во покупок в неделю) / (Среднее кол-во покупок 1 товара в категории в неделю)
df_ranker_train['n_purchases_div_by_mean'] = \
    df_ranker_train.n_purchases_per_week / df_ranker_train.mean_n_purchases_per_week

# Цена
item_price_df = ft.get_price(data_train_ranker)
df_ranker_train = df_ranker_train.merge(item_price_df[['item_id', 'price']], 
                                        on=['item_id'], how='left')

# Цена / Средняя цена товара в категории
df_ranker_train.loc[(df_ranker_train.department == 'PRODUCE') &
                    (df_ranker_train.price == float('Inf')), 'price'] = 0
mean_price_by_department = ft.get_mean_price_by_department(df_ranker_train)
df_ranker_train = df_ranker_train.merge(mean_price_by_department[['department', 'mean_price']], 
                                        on=['department'], how='left')
df_ranker_train['price_div_by_mean_dept_price'] = df_ranker_train.price / df_ranker_train.mean_price
df_ranker_train.drop('mean_price', axis=1, inplace=True)

# %% [markdown]
# ### user_id - item_id

# %%
# (Кол-во покупок юзером конкретной категории в неделю) - (Среднее 
# кол-во покупок всеми юзерами конкретной категории в неделю)
n_purchases_sub_by_mean = ft.get_num_purchases_sub_by_mean(data_train_ranker, item_features)
df_ranker_train = df_ranker_train.merge(n_purchases_sub_by_mean[['user_id', 'department',
        'n_purchases_sub_by_mean']], on=['user_id', 'department'], how='left')

# (Кол-во покупок юзером конкретной категории в неделю) / (Среднее 
# кол-во покупок всеми юзерами конкретной категории в неделю)
n_purchases_div_by_mean = ft.get_num_purchases_div_by_mean_all_users(data_train_ranker, item_features)
df_ranker_train = df_ranker_train.merge(n_purchases_div_by_mean[['user_id', 'department',
        'n_purchases_div_by_mean_all_users']], on=['user_id', 'department'], how='left')

# (Средняя сумма покупки 1 товара в каждой категории (берем категорию item_id)) - (Цена item_id)
sales_values_by_dept = ft.get_mean_sales_value_per_item_by_department(data_train_ranker, item_features)
df_ranker_train = df_ranker_train.merge(sales_values_by_dept[['department', 'mean_sale_sum_per_item']], 
                                        on=['department'], how='left')
df_ranker_train['mean_sale_sum_per_item_sub_price'] = \
    df_ranker_train.mean_sale_sum_per_item - df_ranker_train.price
df_ranker_train.drop('mean_sale_sum_per_item', axis=1, inplace=True)

# %% [markdown]
# Поведенческие фичи

# %%
# Общая сумма покупок каждого товара
total_item_sales_value = ft.get_total_item_sales_value(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(total_item_sales_value, how='left', on='item_id')

# Общее количество по каждому товару
total_quantity_value = ft.get_total_quantity_value(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(total_quantity_value, how='left', on='item_id')

# Количество покупателей по каждому товару
item_freq = ft.get_item_freq(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(item_freq, how='left', on='item_id')

# Частота пользователей
user_freq = ft.get_user_freq(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(user_freq, how='left', on=USER_COL)

# Общее количество покупок по каждому пользователю
total_user_sales_value = ft.get_total_user_sales_value(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(total_user_sales_value, how='left', on='user_id')

# Среднее количество покупок товара в неделю
item_quantity_per_week = ft.get_item_quantity_per_week(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(item_quantity_per_week, how='left', on='item_id')

# Среднее количество купленного товара пользователем в неделю
user_quantity_per_week = ft.get_user_quantity_per_week(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(user_quantity_per_week, how='left', on='user_id')

# Среднее количество товара за 1 покупку
item_quantity_per_basket = ft.get_item_quantity_per_basket(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(item_quantity_per_basket, how='left', on='item_id')

# Среднее количество товара у польователя за 1 покупку
user_quantity_per_basket = ft.get_user_quantity_per_basket(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(user_quantity_per_basket, how='left', on='user_id')

# Средняя частота товара в карзине
item_freq_per_basket = ft.get_item_freq_per_basket(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(item_freq_per_basket, how='left', on='item_id')

# Средняя частота пользователей купивших товар
user_freq_per_basket = ft.get_user_freq_per_basket(df_join_train_matcher)
df_ranker_train = df_ranker_train.merge(user_freq_per_basket, how='left', on='user_id')

# %% [markdown]
# Факторы товаров из модели матричной факторизации

# %%
item_factors = recommender.get_item_factors()
df_ranker_train = df_ranker_train.merge(item_factors, on=['item_id'], how='left')

# %% [markdown]
# Факторы пользователей из модели матричной факторизации

# %%
user_factors = recommender.get_user_factors()
df_ranker_train = df_ranker_train.merge(user_factors, on=['user_id'], how='left')

# %% [markdown]
# ### Разбиваю на X и y

# %%
df_ranker_train.fillna(0, inplace=True)

# %%
df_ranker_train.head()
# Out:
#    user_id  item_id  target  manufacturer  department     brand  \
# 0     2070  1029743     0.0            69     GROCERY   Private
# 1     2070   913210     1.0             2     GROCERY  National
# 2     2070  1105426     0.0            69        DELI   Private
# 3     2070   933067     1.0          1425  MEAT-PCKGD  National
# 4     2070   838186     1.0          1790     GROCERY  National
#
#                    commodity_desc              sub_commodity_desc  \
# 0             FLUID MILK PRODUCTS           FLUID MILK WHITE ONLY
# 1  WATER - CARBONATED/FLVRD DRINK  NON-CRBNTD DRNKING/MNERAL WATE
# 2                      SANDWICHES             SANDWICHES - (COLD)
# 3                           BACON                  FLAVORED/OTHER
# 4               BAKED SWEET GOODS                   SW GDS:DONUTS
#
#   curr_size_of_product age_desc marital_status_code income_desc  \
# 0                 1 GA    45-54                   U      50-74K
# 1             405.6 OZ    45-54                   U      50-74K
# 2                         45-54                   U      50-74K
# 3                16 OZ    45-54                   U      50-74K
# 4              18.2 OZ    45-54                   U      50-74K
#
#   homeowner_desc hh_comp_desc household_size_desc kid_category_desc  \
# 0        Unknown      Unknown                   1      None/Unknown
# 1        Unknown      Unknown                   1      None/Unknown
# 2        Unknown      Unknown                   1      None/Unknown
# 3        Unknown      Unknown                   1      None/Unknown
# 4        Unknown      Unknown                   1      None/Unknown
#
#   item_in_last_5_transactions  mean_purchase  num_purchases  morning_trans  \
# 0                       00000       1.461549           39.0       0.714286
# 1                       00000       1.461549           39.0       0.714286
# 2                       00000       3.596667            2.0       0.714286
# 3                       00000       3.426364            3.0       0.714286
# 4                       00000       1.461549           39.0       0.714286
#
#    day_trans  evening_trans  n_purchases_per_week  mean_n_purchases_per_week  \
# 0        0.0       0.285714            179.333333                   2.499367
# 1        0.0       0.285714             17.666667                   2.499367
# 2        0.0       0.285714              1.000000                   2.260583
# 3        0.0       0.285714              7.333333                   2.369450
# 4        0.0       0.285714              7.500000                   2.499367
#
#    n_purchases_div_by_mean     price  price_div_by_mean_dept_price  \
# 0                71.751510  2.682058                      0.655522
# 1                 7.068457  3.990000                      0.975196
# 2                 0.442364  3.990000                      0.861000
# 3                 3.094952  3.990000                      0.840420
# 4                 3.000760  3.990000                      0.975196
#
#    n_purchases_sub_by_mean  n_purchases_div_by_mean_all_users  \
# 0                 6.192347                          21.127701
# 1                 6.192347                          21.127701
# 2                 0.808016                           5.208760
# 3                 0.802530                           5.064053
# 4                 6.192347                          21.127701
#
#    mean_sale_sum_per_item_sub_price  total_item_sales_value  \
# 0                         -0.150089                35764.66
# 1                         -1.458031                 5406.18
# 2                          0.537463                  442.90
# 3                         -0.155712                 1974.07
# 4                         -1.458031                 2848.27
#
#    total_quantity_value  item_freq  user_freq  total_user_sales_value  \
# 0                 15015      12737       1996                 5754.86
# 1                  1364       1175       1996                 5754.86
# 2                   113         99       1996                 5754.86
# 3                   711        520       1996                 5754.86
# 4                   752        694       1996                 5754.86
#
#    item_quantity_per_week  user_quantity_per_week  item_quantity_per_basket  \
# 0              165.000000              1218.32967                  0.061233
# 1               14.989011              1218.32967                  0.005563
# 2                1.241758              1218.32967                  0.000461
# 3                7.813187              1218.32967                  0.002900
# 4                8.263736              1218.32967                  0.003067
#
#    user_quantity_per_basket  item_freq_per_basket  user_freq_per_basket  \
# 0                  0.452137              0.051943               0.00814
# 1                  0.452137              0.004792               0.00814
# 2                  0.452137              0.000404               0.00814
# 3                  0.452137              0.002121               0.00814
# 4                  0.452137              0.002830               0.00814
#
#    item_factor_0  item_factor_1  item_factor_2  item_factor_3  item_factor_4  \
# 0       0.066465       0.026564       0.115785       0.020399       0.052085
# 1       0.059623      -0.034862       0.048245       0.014096       0.035486
# 2       0.011821       0.020220       0.022124      -0.003266       0.007878
# 3       0.031612       0.049280       0.019087       0.029102       0.030467
# 4       0.056060       0.006627       0.062418       0.010776       0.058622
#
#    item_factor_5  item_factor_6  item_factor_7  item_factor_8  item_factor_9  \
# 0       0.018378       0.034077       0.020123      -0.018639       0.025482
# 1       0.040294       0.002642       0.050328       0.058283       0.071104
# 2       0.032496      -0.011329      -0.002333       0.026204       0.008198
# 3      -0.006045       0.042394       0.001145       0.028372       0.011762
# 4       0.046359       0.054751       0.059989       0.012659       0.044626
#
#    item_factor_10  item_factor_11  item_factor_12  item_factor_13  \
# 0        0.034647        0.064597        0.019448        0.002459
# 1       -0.011521        0.041084        0.064835        0.006787
# 2       -0.025307        0.014758        0.004584        0.020256
# 3        0.065151        0.072213        0.044012        0.009182
# 4        0.008342        0.029874        0.041143       -0.011917
#
#    item_factor_14  item_factor_15  item_factor_16  item_factor_17  \
# 0        0.062425        0.027316        0.030092        0.101295
# 1        0.035533        0.021060        0.018043        0.030404
# 2        0.006443       -0.007712       -0.005453        0.003935
# 3       -0.007959        0.010895       -0.005781        0.090651
# 4        0.070987        0.009419       -0.016196        0.058370
#
#    item_factor_18  item_factor_19  user_factor_0  user_factor_1  \
# 0        0.121174        0.086379        1.86111       1.653347
# 1        0.093669        0.034801        1.86111       1.653347
# 2        0.005894        0.020193        1.86111       1.653347
# 3        0.010950        0.005597        1.86111       1.653347
# 4        0.031780        0.028939        1.86111       1.653347
#
#    user_factor_2  user_factor_3  user_factor_4  user_factor_5  user_factor_6  \
# 0       3.124222       2.104717      -0.488921       0.495965       1.286621
# 1       3.124222       2.104717      -0.488921       0.495965       1.286621
# 2       3.124222       2.104717      -0.488921       0.495965       1.286621
# 3       3.124222       2.104717      -0.488921       0.495965       1.286621
# 4       3.124222       2.104717      -0.488921       0.495965       1.286621
#
#    user_factor_7  user_factor_8  user_factor_9  user_factor_10  \
# 0       2.274672       1.392407      -0.224331       -1.356235
# 1       2.274672       1.392407      -0.224331       -1.356235
# 2       2.274672       1.392407      -0.224331       -1.356235
# 3       2.274672       1.392407      -0.224331       -1.356235
# 4       2.274672       1.392407      -0.224331       -1.356235
#
#    user_factor_11  user_factor_12  user_factor_13  user_factor_14  \
# 0        0.561147        0.983569       -1.059754       -1.361881
# 1        0.561147        0.983569       -1.059754       -1.361881
# 2        0.561147        0.983569       -1.059754       -1.361881
# 3        0.561147        0.983569       -1.059754       -1.361881
# 4        0.561147        0.983569       -1.059754       -1.361881
#
#    user_factor_15  user_factor_16  user_factor_17  user_factor_18  \
# 0        -2.61805        3.619438        2.754422        2.089347
# 1        -2.61805        3.619438        2.754422        2.089347
# 2        -2.61805        3.619438        2.754422        2.089347
# 3        -2.61805        3.619438        2.754422        2.089347
# 4        -2.61805        3.619438        2.754422        2.089347
#
#    user_factor_19
# 0         0.12518
# 1         0.12518
# 2         0.12518
# 3         0.12518
# 4         0.12518

# %%
X_train = df_ranker_train.drop('target', axis=1)
y_train = df_ranker_train[['target']]

# %%
cat_feats = X_train.columns[2:16].tolist()
X_train[cat_feats] = X_train[cat_feats].astype('category')

# %% [markdown]
# ## Обучение модели ранжирования

# %%
cb = CatBoost()

# %%
cb.fit(X_train, y_train, cat_features=cat_feats)

train_preds = cb.predict_proba(X_train)
# Out:
# Learning rate set to 0.06739
# 0:	learn: 0.4316849	total: 210ms	remaining: 3m 29s
# 234:	learn: 0.3495894	total: 10.4s	remaining: 33.8s
# 235:	learn: 0.3494312	total: 10.5s	remaining: 33.9s
# 236:	learn: 0.3493231	total: 10.5s	remaining: 33.8s
# 237:	learn: 0.3491663	total: 10.5s	remaining: 33.8s
# 238:	learn: 0.3491321	total: 10.6s	remaining: 33.7s
# 239:	learn: 0.3489946	total: 10.6s	remaining: 33.7s
# 240:	learn: 0.3488255	total: 10.7s	remaining: 33.6s
# 241:	learn: 0.3487183	total: 10.7s	remaining: 33.5s
# 242:	learn: 0.3486345	total: 10.7s	remaining: 33.5s
# 243:	learn: 0.3486241	total: 10.8s	remaining: 33.4s
# 244:	learn: 0.3484730	total: 10.8s	remaining: 33.4s
# 245:	learn: 0.3483991	total: 10.9s	remaining: 33.3s
# 246:	learn: 0.3483136	total: 10.9s	remaining: 33.4s
# 247:	learn: 0.3482746	total: 11s	remaining: 33.4s
# 248:	learn: 0.3482744	total: 11.1s	remaining: 33.4s
# 249:	learn: 0.3481849	total: 11.1s	remaining: 33.3s
# 250:	learn: 0.3480608	total: 11.1s	remaining: 33.3s
# 251:	learn: 0.3478906	total: 11.2s	remaining: 33.2s
# 252:	learn: 0.3477832	total: 11.2s	remaining: 33.1s
# 253:	learn: 0.3476455	total: 11.3s	remaining: 33.1s
# 254:	learn: 0.3474923	total: 11.3s	remaining: 33.1s
# 255:	learn: 0.3474916	total: 11.3s	remaining: 33s
# 256:	learn: 0.3473807	total: 11.4s	remaining: 32.9s
# 257:	learn: 0.3472575	total: 11.4s	remaining: 32.9s
# 258:	learn: 0.3471115	total: 11.5s	remaining: 32.8s
# 259:	learn: 0.3470391	total: 11.5s	remaining: 32.7s
# 260:	learn: 0.3469304	total: 11.5s	remaining: 32.7s
# 261:	learn: 0.3468155	total: 11.6s	remaining: 32.6s
# 262:	learn: 0.3466702	total: 11.6s	remaining: 32.6s
# 263:	learn: 0.3466234	total: 11.7s	remaining: 32.5s
# 264:	learn: 0.3465208	total: 11.7s	remaining: 32.5s
# 265:	learn: 0.3463665	total: 11.7s	remaining: 32.4s
# 266:	learn: 0.3462577	total: 11.8s	remaining: 32.4s
# 267:	learn: 0.3462359	total: 11.8s	remaining: 32.3s
# 268:	learn: 0.3460813	total: 11.9s	remaining: 32.2s
# 269:	learn: 0.3459515	total: 11.9s	remaining: 32.2s
# 270:	learn: 0.3458585	total: 11.9s	remaining: 32.1s
# 271:	learn: 0.3457347	total: 12s	remaining: 32.1s
# 272:	learn: 0.3456314	total: 12s	remaining: 32s
# 273:	learn: 0.3454794	total: 12.1s	remaining: 32s
# 274:	learn: 0.3453826	total: 12.1s	remaining: 31.9s
# 275:	learn: 0.3452505	total: 12.2s	remaining: 31.9s
# 276:	learn: 0.3451266	total: 12.2s	remaining: 31.8s
# 277:	learn: 0.3449885	total: 12.2s	remaining: 31.8s
# 278:	learn: 0.3448494	total: 12.3s	remaining: 31.7s
# 279:	learn: 0.3447483	total: 12.3s	remaining: 31.7s
# 280:	learn: 0.3445980	total: 12.4s	remaining: 31.7s
# 327:	learn: 0.3402357	total: 14.4s	remaining: 29.5s
# 328:	learn: 0.3402300	total: 14.5s	remaining: 29.5s
# 329:	learn: 0.3402027	total: 14.5s	remaining: 29.4s
# 330:	learn: 0.3401654	total: 14.5s	remaining: 29.4s
# 331:	learn: 0.3400365	total: 14.6s	remaining: 29.3s
# 332:	learn: 0.3399347	total: 14.6s	remaining: 29.3s
# 333:	learn: 0.3398279	total: 14.7s	remaining: 29.3s
# 334:	learn: 0.3397791	total: 14.7s	remaining: 29.2s
# 335:	learn: 0.3396314	total: 14.8s	remaining: 29.2s
# 336:	learn: 0.3395275	total: 14.8s	remaining: 29.1s
# 337:	learn: 0.3394654	total: 14.9s	remaining: 29.1s
# 338:	learn: 0.3394649	total: 14.9s	remaining: 29s
# 339:	learn: 0.3393492	total: 14.9s	remaining: 29s
# 340:	learn: 0.3392705	total: 15s	remaining: 28.9s
# 341:	learn: 0.3391805	total: 15s	remaining: 28.9s
# 342:	learn: 0.3390809	total: 15.1s	remaining: 28.9s
# 343:	learn: 0.3389766	total: 15.1s	remaining: 28.8s
# 344:	learn: 0.3389690	total: 15.1s	remaining: 28.8s
# 345:	learn: 0.3388561	total: 15.2s	remaining: 28.7s
# 346:	learn: 0.3388011	total: 15.2s	remaining: 28.7s
# 347:	learn: 0.3387696	total: 15.3s	remaining: 28.6s
# 348:	learn: 0.3386906	total: 15.3s	remaining: 28.6s
# 349:	learn: 0.3385365	total: 15.4s	remaining: 28.5s
# 350:	learn: 0.3384933	total: 15.4s	remaining: 28.5s
# 351:	learn: 0.3383769	total: 15.4s	remaining: 28.4s
# 352:	learn: 0.3383064	total: 15.5s	remaining: 28.4s
# 353:	learn: 0.3382098	total: 15.5s	remaining: 28.3s
# 354:	learn: 0.3381463	total: 15.6s	remaining: 28.3s
# 355:	learn: 0.3380013	total: 15.6s	remaining: 28.2s
# 356:	learn: 0.3379129	total: 15.7s	remaining: 28.2s
# 357:	learn: 0.3377870	total: 15.7s	remaining: 28.1s
# 358:	learn: 0.3376582	total: 15.7s	remaining: 28.1s
# 359:	learn: 0.3375323	total: 15.8s	remaining: 28s
# 360:	learn: 0.3374781	total: 15.8s	remaining: 28s
# 361:	learn: 0.3373913	total: 15.9s	remaining: 27.9s
# 362:	learn: 0.3372939	total: 15.9s	remaining: 27.9s
# 363:	learn: 0.3371444	total: 15.9s	remaining: 27.8s
# 364:	learn: 0.3370391	total: 16s	remaining: 27.8s
# 365:	learn: 0.3369688	total: 16s	remaining: 27.7s
# 366:	learn: 0.3368939	total: 16s	remaining: 27.7s
# 367:	learn: 0.3367794	total: 16.1s	remaining: 27.6s
# 368:	learn: 0.3367582	total: 16.1s	remaining: 27.6s
# 369:	learn: 0.3366862	total: 16.2s	remaining: 27.5s
# 370:	learn: 0.3366173	total: 16.2s	remaining: 27.5s
# 371:	learn: 0.3365622	total: 16.3s	remaining: 27.5s
# 372:	learn: 0.3365204	total: 16.3s	remaining: 27.4s
# 373:	learn: 0.3364552	total: 16.4s	remaining: 27.4s
# 655:	learn: 0.3165951	total: 28.1s	remaining: 14.7s
# 656:	learn: 0.3164957	total: 28.2s	remaining: 14.7s
# 657:	learn: 0.3164577	total: 28.2s	remaining: 14.7s
# 658:	learn: 0.3163920	total: 28.2s	remaining: 14.6s
# 659:	learn: 0.3163592	total: 28.3s	remaining: 14.6s
# 660:	learn: 0.3162482	total: 28.3s	remaining: 14.5s
# 661:	learn: 0.3160974	total: 28.4s	remaining: 14.5s
# 662:	learn: 0.3160105	total: 28.4s	remaining: 14.4s
# 663:	learn: 0.3160040	total: 28.5s	remaining: 14.4s
# 664:	learn: 0.3159465	total: 28.5s	remaining: 14.4s
# 665:	learn: 0.3158772	total: 28.6s	remaining: 14.3s
# 666:	learn: 0.3157688	total: 28.6s	remaining: 14.3s
# 667:	learn: 0.3156976	total: 28.6s	remaining: 14.2s
# 668:	learn: 0.3156063	total: 28.7s	remaining: 14.2s
# 669:	learn: 0.3155611	total: 28.7s	remaining: 14.1s
# 670:	learn: 0.3154511	total: 28.8s	remaining: 14.1s
# 671:	learn: 0.3153598	total: 28.8s	remaining: 14.1s
# 672:	learn: 0.3152883	total: 28.9s	remaining: 14s
# 673:	learn: 0.3152457	total: 28.9s	remaining: 14s
# 674:	learn: 0.3151613	total: 28.9s	remaining: 13.9s
# 675:	learn: 0.3150622	total: 29s	remaining: 13.9s
# 676:	learn: 0.3150071	total: 29s	remaining: 13.8s
# 677:	learn: 0.3149156	total: 29.1s	remaining: 13.8s
# 678:	learn: 0.3148314	total: 29.1s	remaining: 13.8s
# 679:	learn: 0.3147705	total: 29.1s	remaining: 13.7s
# 680:	learn: 0.3147037	total: 29.2s	remaining: 13.7s
# 681:	learn: 0.3146322	total: 29.2s	remaining: 13.6s
# 682:	learn: 0.3145290	total: 29.3s	remaining: 13.6s
# 683:	learn: 0.3144351	total: 29.3s	remaining: 13.5s
# 684:	learn: 0.3143443	total: 29.3s	remaining: 13.5s
# 685:	learn: 0.3142869	total: 29.4s	remaining: 13.4s
# 686:	learn: 0.3142757	total: 29.4s	remaining: 13.4s
# 687:	learn: 0.3142189	total: 29.5s	remaining: 13.4s
# 688:	learn: 0.3141321	total: 29.5s	remaining: 13.3s
# 689:	learn: 0.3140820	total: 29.5s	remaining: 13.3s
# 690:	learn: 0.3139828	total: 29.6s	remaining: 13.2s
# 691:	learn: 0.3138830	total: 29.6s	remaining: 13.2s
# 692:	learn: 0.3138453	total: 29.7s	remaining: 13.1s
# 693:	learn: 0.3137704	total: 29.7s	remaining: 13.1s
# 694:	learn: 0.3137538	total: 29.7s	remaining: 13s
# 695:	learn: 0.3137105	total: 29.8s	remaining: 13s
# 696:	learn: 0.3135759	total: 29.8s	remaining: 13s
# 697:	learn: 0.3135502	total: 29.9s	remaining: 12.9s
# 698:	learn: 0.3134334	total: 29.9s	remaining: 12.9s
# 699:	learn: 0.3133670	total: 29.9s	remaining: 12.8s
# 700:	learn: 0.3132860	total: 30s	remaining: 12.8s
# 701:	learn: 0.3132158	total: 30s	remaining: 12.7s
# 702:	learn: 0.3130984	total: 30.1s	remaining: 12.7s
# 703:	learn: 0.3130421	total: 30.1s	remaining: 12.7s
# 704:	learn: 0.3129820	total: 30.1s	remaining: 12.6s
# 705:	learn: 0.3128924	total: 30.2s	remaining: 12.6s
# 706:	learn: 0.3128521	total: 30.2s	remaining: 12.5s
# 707:	learn: 0.3127526	total: 30.3s	remaining: 12.5s
# 708:	learn: 0.3126623	total: 30.3s	remaining: 12.4s
# 709:	learn: 0.3125270	total: 30.4s	remaining: 12.4s
# 710:	learn: 0.3124341	total: 30.4s	remaining: 12.4s
# 711:	learn: 0.3123340	total: 30.5s	remaining: 12.3s
# 712:	learn: 0.3122733	total: 30.5s	remaining: 12.3s
# 713:	learn: 0.3122494	total: 30.5s	remaining: 12.2s
# 714:	learn: 0.3121838	total: 30.6s	remaining: 12.2s
# 715:	learn: 0.3121503	total: 30.6s	remaining: 12.1s
# 716:	learn: 0.3120791	total: 30.7s	remaining: 12.1s
# 717:	learn: 0.3120348	total: 30.7s	remaining: 12.1s
# 718:	learn: 0.3119741	total: 30.7s	remaining: 12s
# 719:	learn: 0.3119064	total: 30.8s	remaining: 12s
# 720:	learn: 0.3117952	total: 30.8s	remaining: 11.9s
# 721:	learn: 0.3116976	total: 30.8s	remaining: 11.9s
# 722:	learn: 0.3116226	total: 30.9s	remaining: 11.8s
# 723:	learn: 0.3114939	total: 30.9s	remaining: 11.8s
# 724:	learn: 0.3114936	total: 31s	remaining: 11.7s
# 725:	learn: 0.3113912	total: 31s	remaining: 11.7s
# 726:	learn: 0.3113057	total: 31.1s	remaining: 11.7s
# 727:	learn: 0.3112475	total: 31.1s	remaining: 11.6s
# 728:	learn: 0.3111739	total: 31.1s	remaining: 11.6s
# 729:	learn: 0.3111394	total: 31.2s	remaining: 11.5s
# 730:	learn: 0.3110392	total: 31.2s	remaining: 11.5s
# 731:	learn: 0.3109647	total: 31.3s	remaining: 11.4s
# 732:	learn: 0.3109031	total: 31.3s	remaining: 11.4s
# 733:	learn: 0.3108593	total: 31.3s	remaining: 11.4s
# 734:	learn: 0.3107719	total: 31.4s	remaining: 11.3s
# 735:	learn: 0.3106523	total: 31.4s	remaining: 11.3s
# 736:	learn: 0.3106202	total: 31.5s	remaining: 11.2s
# 737:	learn: 0.3105815	total: 31.5s	remaining: 11.2s
# 738:	learn: 0.3104893	total: 31.6s	remaining: 11.1s
# 739:	learn: 0.3104413	total: 31.6s	remaining: 11.1s
# 740:	learn: 0.3104021	total: 31.6s	remaining: 11.1s
# 741:	learn: 0.3102609	total: 31.7s	remaining: 11s
# 742:	learn: 0.3101870	total: 31.7s	remaining: 11s
# 743:	learn: 0.3100860	total: 31.8s	remaining: 10.9s
# 744:	learn: 0.3100003	total: 31.8s	remaining: 10.9s
# 745:	learn: 0.3098997	total: 31.8s	remaining: 10.8s
# 746:	learn: 0.3098161	total: 31.9s	remaining: 10.8s
# 747:	learn: 0.3097942	total: 31.9s	remaining: 10.8s
# 748:	learn: 0.3097268	total: 32s	remaining: 10.7s
# 749:	learn: 0.3096833	total: 32s	remaining: 10.7s
# 750:	learn: 0.3096264	total: 32s	remaining: 10.6s
# 751:	learn: 0.3094948	total: 32.1s	remaining: 10.6s
# 752:	learn: 0.3094410	total: 32.1s	remaining: 10.5s
# 753:	learn: 0.3093411	total: 32.2s	remaining: 10.5s
# 754:	learn: 0.3092852	total: 32.2s	remaining: 10.5s
# 755:	learn: 0.3091920	total: 32.2s	remaining: 10.4s
# 756:	learn: 0.3091235	total: 32.3s	remaining: 10.4s
# 757:	learn: 0.3090781	total: 32.3s	remaining: 10.3s
# 758:	learn: 0.3090405	total: 32.4s	remaining: 10.3s
# 759:	learn: 0.3089395	total: 32.4s	remaining: 10.2s
# 760:	learn: 0.3088670	total: 32.5s	remaining: 10.2s
# 761:	learn: 0.3088041	total: 32.5s	remaining: 10.1s
# 762:	learn: 0.3087695	total: 32.5s	remaining: 10.1s
# 763:	learn: 0.3086747	total: 32.6s	remaining: 10.1s
# 764:	learn: 0.3085913	total: 32.6s	remaining: 10s
# 765:	learn: 0.3085799	total: 32.7s	remaining: 9.97s
# 766:	learn: 0.3084808	total: 32.7s	remaining: 9.93s
# 767:	learn: 0.3084440	total: 32.7s	remaining: 9.89s
# 768:	learn: 0.3083664	total: 32.8s	remaining: 9.85s
# 769:	learn: 0.3082530	total: 32.8s	remaining: 9.8s
# 770:	learn: 0.3081556	total: 32.9s	remaining: 9.76s
# 771:	learn: 0.3080749	total: 32.9s	remaining: 9.72s
# 772:	learn: 0.3080124	total: 32.9s	remaining: 9.67s
# 773:	learn: 0.3079268	total: 33s	remaining: 9.63s
# 774:	learn: 0.3078918	total: 33s	remaining: 9.59s
# 775:	learn: 0.3078241	total: 33.1s	remaining: 9.54s
# 776:	learn: 0.3077613	total: 33.1s	remaining: 9.5s
# 777:	learn: 0.3076768	total: 33.2s	remaining: 9.46s
# 778:	learn: 0.3076592	total: 33.2s	remaining: 9.42s
# 779:	learn: 0.3076240	total: 33.3s	remaining: 9.39s
# 780:	learn: 0.3075118	total: 33.3s	remaining: 9.35s
# 781:	learn: 0.3074432	total: 33.4s	remaining: 9.31s
# 782:	learn: 0.3073942	total: 33.4s	remaining: 9.26s
# 783:	learn: 0.3073711	total: 33.5s	remaining: 9.22s
# 784:	learn: 0.3073110	total: 33.5s	remaining: 9.18s
# 785:	learn: 0.3072484	total: 33.5s	remaining: 9.13s
# 786:	learn: 0.3071536	total: 33.6s	remaining: 9.09s
# 787:	learn: 0.3070499	total: 33.6s	remaining: 9.05s
# 788:	learn: 0.3069631	total: 33.7s	remaining: 9s
# 789:	learn: 0.3068818	total: 33.7s	remaining: 8.96s
# 790:	learn: 0.3068150	total: 33.7s	remaining: 8.92s
# 791:	learn: 0.3067594	total: 33.8s	remaining: 8.87s
# 792:	learn: 0.3066982	total: 33.8s	remaining: 8.83s
# 793:	learn: 0.3066208	total: 33.9s	remaining: 8.79s
# 794:	learn: 0.3065547	total: 33.9s	remaining: 8.74s
# 934:	learn: 0.2974358	total: 39.6s	remaining: 2.75s
# 935:	learn: 0.2973251	total: 39.6s	remaining: 2.71s
# 936:	learn: 0.2972857	total: 39.7s	remaining: 2.67s
# 937:	learn: 0.2972310	total: 39.7s	remaining: 2.63s
# 938:	learn: 0.2972039	total: 39.8s	remaining: 2.58s
# 939:	learn: 0.2970903	total: 39.8s	remaining: 2.54s
# 940:	learn: 0.2970020	total: 39.8s	remaining: 2.5s
# 941:	learn: 0.2969406	total: 39.9s	remaining: 2.46s
# 942:	learn: 0.2969322	total: 39.9s	remaining: 2.41s
# 943:	learn: 0.2968723	total: 40s	remaining: 2.37s
# 944:	learn: 0.2968065	total: 40s	remaining: 2.33s
# 945:	learn: 0.2967877	total: 40.1s	remaining: 2.29s
# 946:	learn: 0.2967253	total: 40.1s	remaining: 2.24s
# 947:	learn: 0.2966955	total: 40.1s	remaining: 2.2s
# 948:	learn: 0.2966649	total: 40.2s	remaining: 2.16s
# 949:	learn: 0.2966450	total: 40.2s	remaining: 2.12s
# 950:	learn: 0.2965876	total: 40.3s	remaining: 2.07s
# 951:	learn: 0.2965131	total: 40.3s	remaining: 2.03s
# 952:	learn: 0.2964091	total: 40.3s	remaining: 1.99s
# 953:	learn: 0.2963608	total: 40.4s	remaining: 1.95s
# 954:	learn: 0.2962957	total: 40.4s	remaining: 1.9s
# 955:	learn: 0.2962781	total: 40.5s	remaining: 1.86s
# 956:	learn: 0.2962009	total: 40.5s	remaining: 1.82s
# 957:	learn: 0.2961364	total: 40.5s	remaining: 1.78s
# 958:	learn: 0.2960641	total: 40.6s	remaining: 1.73s
# 959:	learn: 0.2960381	total: 40.6s	remaining: 1.69s
# 960:	learn: 0.2959320	total: 40.7s	remaining: 1.65s
# 961:	learn: 0.2958456	total: 40.7s	remaining: 1.61s
# 962:	learn: 0.2957865	total: 40.7s	remaining: 1.56s
# 963:	learn: 0.2957386	total: 40.8s	remaining: 1.52s
# 964:	learn: 0.2956113	total: 40.8s	remaining: 1.48s
# 965:	learn: 0.2955429	total: 40.8s	remaining: 1.44s
# 966:	learn: 0.2954684	total: 40.9s	remaining: 1.4s
# 967:	learn: 0.2954193	total: 40.9s	remaining: 1.35s
# 968:	learn: 0.2953459	total: 41s	remaining: 1.31s
# 969:	learn: 0.2952608	total: 41s	remaining: 1.27s
# 970:	learn: 0.2952163	total: 41.1s	remaining: 1.23s
# 971:	learn: 0.2951476	total: 41.1s	remaining: 1.18s
# 972:	learn: 0.2950535	total: 41.1s	remaining: 1.14s
# 973:	learn: 0.2950090	total: 41.2s	remaining: 1.1s
# 974:	learn: 0.2949796	total: 41.2s	remaining: 1.06s
# 975:	learn: 0.2948959	total: 41.3s	remaining: 1.01s
# 976:	learn: 0.2948362	total: 41.3s	remaining: 972ms
# 977:	learn: 0.2947515	total: 41.3s	remaining: 930ms
# 978:	learn: 0.2947060	total: 41.4s	remaining: 887ms
# 979:	learn: 0.2947039	total: 41.4s	remaining: 845ms
# 980:	learn: 0.2946601	total: 41.5s	remaining: 803ms
# 981:	learn: 0.2945776	total: 41.5s	remaining: 761ms
# 982:	learn: 0.2944837	total: 41.5s	remaining: 718ms
# 983:	learn: 0.2944409	total: 41.6s	remaining: 676ms
# 984:	learn: 0.2943739	total: 41.6s	remaining: 634ms
# 985:	learn: 0.2943168	total: 41.6s	remaining: 591ms
# 986:	learn: 0.2943062	total: 41.7s	remaining: 549ms
# 987:	learn: 0.2942487	total: 41.7s	remaining: 507ms
# 988:	learn: 0.2942310	total: 41.8s	remaining: 465ms
# 989:	learn: 0.2941703	total: 41.8s	remaining: 422ms
# 990:	learn: 0.2941019	total: 41.8s	remaining: 380ms
# 991:	learn: 0.2940583	total: 41.9s	remaining: 338ms
# 992:	learn: 0.2939991	total: 41.9s	remaining: 296ms
# 993:	learn: 0.2939266	total: 42s	remaining: 253ms
# 994:	learn: 0.2938800	total: 42s	remaining: 211ms
# 995:	learn: 0.2938123	total: 42s	remaining: 169ms
# 996:	learn: 0.2937966	total: 42.1s	remaining: 127ms
# 997:	learn: 0.2937735	total: 42.1s	remaining: 84.4ms
# 998:	learn: 0.2937730	total: 42.2s	remaining: 42.2ms
# 999:	learn: 0.2937418	total: 42.2s	remaining: 0us
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-8fd19b17423f> in <module>
#       1 cb.fit(X_train, y_train, cat_features=cat_feats)
#       2
# ----> 3 train_preds = lgb.predict_proba(X_train)
#
# NameError: name 'lgb' is not defined

# %%
df_ranker_predict = df_ranker_train.copy()

# %%
df_ranker_predict['proba_item_purchase'] = train_preds[:,1]

# %%
df_ranker_predict.head()

# %% [markdown]
# # Evaluation on test dataset

# %%
print('Matcher\'s precision:')
for el in recs_type_list:
    res = recommender.evalMetrics(metric_type='precision', df_result=data_val_matcher, 
                    target_col_name=USER_COL, recommend_model_type=el, N_PREDICT=TOPK_PRECISION)
    print(f'{el} precision: {res}')

# %%
print('Ranker\'s precision:')
for el in recs_type_list:
    res = recommender.evalMetrics(metric_type='precision', df_result=data_val_ranker, 
                                    target_col_name=USER_COL, recommend_model_type=el, 
                                    N_PREDICT=TOPK_PRECISION)
    print(f'{el} precision: {res}')

# %% [markdown]
# ## Eval re-ranked matched result on test dataset

# %%
print('Re-ranked precision:')
recommender.reranked_metrics(metric_type='precision', df_result=data_val_ranker, 
                             df_predict=df_ranker_predict, target_col_name=USER_COL, 
                             recommend_model_type='rec', N_PREDICT=TOPK_PRECISION)

# %% [markdown]
# # Оценка на тесте для выполнения курсового проекта

# %%
df_test = pd.read_csv('./data/retail_test1.csv')
df_test.head()

# %%
# warm start
df_test = df_test[df_test.user_id.isin(common_users)]
print_stats_data(df_test,'df_test')

# %%
print('Test precision:')
recommender.evalMetrics(metric_type='precision', df_result=df_test, 
                          target_col_name=USER_COL, recommend_model_type='own', 
                          N_PREDICT=TOPK_PRECISION)

# %%
print('Test re-ranked precision:')
recommender.reranked_metrics(metric_type='precision', df_result=df_test, 
                             df_predict=df_ranker_predict, target_col_name=USER_COL, 
                             recommend_model_type='own', N_PREDICT=TOPK_PRECISION)
